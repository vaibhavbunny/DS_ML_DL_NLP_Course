# %%
# !pip install pandas

# %%
import pandas as pd
df = pd.read_csv('sales_data_sample.csv')
df.head(5)
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# Cell In[7], line 2
#       1 import pandas as pd
# ----> 2 df = pd.read_csv('sales_data_sample.csv')
#       3 df.head(5)
#
# File ~/ML Learnings/venv/lib/python3.10/site-packages/pandas/io/parsers/readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
import pandas as pd

# Try these encodings in order
encodings = ['latin-1', 'iso-8859-1', 'cp1252']

for encoding in encodings:
    try:
        df = pd.read_csv('sales_data_sample.csv', encoding=encoding)
        print(f"Successfully read file with {encoding} encoding")
        break
    except UnicodeDecodeError:
        continue
# Out:
# Successfully read file with latin-1 encoding

# %%
df
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0           10107               30      95.70                2  2871.00
# 1           10121               34      81.35                5  2765.90
# 2           10134               41      94.74                2  3884.34
# 3           10145               45      83.26                6  3746.70
# 4           10159               49     100.00               14  5205.27
# ...           ...              ...        ...              ...      ...
# 2818        10350               20     100.00               15  2244.40
# 2819        10373               29     100.00                1  3978.51
# 2820        10386               43     100.00                4  5417.57
# 2821        10397               34      62.24                1  2116.16
# 2822        10414               47      65.52                9  3079.44
#
#             ORDERDATE    STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# ...

# %%
df.head(5)
# Out:
#    ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0        10107               30      95.70                2  2871.00
# 1        10121               34      81.35                5  2765.90
# 2        10134               41      94.74                2  3884.34
# 3        10145               45      83.26                6  3746.70
# 4        10159               49     100.00               14  5205.27
#
#          ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 0   2/24/2003 0:00  Shipped       1         2     2003  ...
# 1    5/7/2003 0:00  Shipped       2         5     2003  ...
# 2    7/1/2003 0:00  Shipped       3         7     2003  ...
# 3   8/25/2003 0:00  Shipped       3         8     2003  ...
# 4  10/10/2003 0:00  Shipped       4        10     2003  ...
#
#                     ADDRESSLINE1  ADDRESSLINE2           CITY STATE  \
# 0        897 Long Airport Avenue           NaN            NYC    NY
# ...

# %%
df.describe()
# Out:
#         ORDERNUMBER  QUANTITYORDERED    PRICEEACH  ORDERLINENUMBER  \
# count   2823.000000      2823.000000  2823.000000      2823.000000
# mean   10258.725115        35.092809    83.658544         6.466171
# std       92.085478         9.741443    20.174277         4.225841
# min    10100.000000         6.000000    26.880000         1.000000
# 25%    10180.000000        27.000000    68.860000         3.000000
# 50%    10262.000000        35.000000    95.700000         6.000000
# 75%    10333.500000        43.000000   100.000000         9.000000
# max    10425.000000        97.000000   100.000000        18.000000
#
#               SALES       QTR_ID     MONTH_ID     YEAR_ID         MSRP
# count   2823.000000  2823.000000  2823.000000  2823.00000  2823.000000
# mean    3553.889072     2.717676     7.092455  2003.81509   100.715551
# std     1841.865106     1.203878     3.656633     0.69967    40.187912
# min      482.130000     1.000000     1.000000  2003.00000    33.000000
# ...

# %%
df.dtypes
# Out:
# ORDERNUMBER           int64
# QUANTITYORDERED       int64
# PRICEEACH           float64
# ORDERLINENUMBER       int64
# SALES               float64
# ORDERDATE            object
# STATUS               object
# QTR_ID                int64
# MONTH_ID              int64
# YEAR_ID               int64
# PRODUCTLINE          object
# MSRP                  int64
# PRODUCTCODE          object
# CUSTOMERNAME         object
# PHONE                object
# ADDRESSLINE1         object
# ADDRESSLINE2         object
# CITY                 object
# STATE                object
# POSTALCODE           object
# COUNTRY              object
# TERRITORY            object
# CONTACTLASTNAME      object
# CONTACTFIRSTNAME     object
# DEALSIZE             object
# dtype: object

# %%
# Handling Missing Values 
df.isnull()
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER  SALES  \
# 0           False            False      False            False  False
# 1           False            False      False            False  False
# 2           False            False      False            False  False
# 3           False            False      False            False  False
# 4           False            False      False            False  False
# ...           ...              ...        ...              ...    ...
# 2818        False            False      False            False  False
# 2819        False            False      False            False  False
# 2820        False            False      False            False  False
# 2821        False            False      False            False  False
# 2822        False            False      False            False  False
#
#       ORDERDATE  STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  ADDRESSLINE1  \
# ...

# %%
df.isnull().any()
# Out:
# ORDERNUMBER         False
# QUANTITYORDERED     False
# PRICEEACH           False
# ORDERLINENUMBER     False
# SALES               False
# ORDERDATE           False
# STATUS              False
# QTR_ID              False
# MONTH_ID            False
# YEAR_ID             False
# PRODUCTLINE         False
# MSRP                False
# PRODUCTCODE         False
# CUSTOMERNAME        False
# PHONE               False
# ADDRESSLINE1        False
# ADDRESSLINE2         True
# CITY                False
# STATE                True
# POSTALCODE           True
# COUNTRY             False
# TERRITORY            True
# CONTACTLASTNAME     False
# CONTACTFIRSTNAME    False
# DEALSIZE            False
# dtype: bool

# %%
df.isnull().sum() ### will give the total number of missing values in a particular column
# Out:
# ORDERNUMBER            0
# QUANTITYORDERED        0
# PRICEEACH              0
# ORDERLINENUMBER        0
# SALES                  0
# ORDERDATE              0
# STATUS                 0
# QTR_ID                 0
# MONTH_ID               0
# YEAR_ID                0
# PRODUCTLINE            0
# MSRP                   0
# PRODUCTCODE            0
# CUSTOMERNAME           0
# PHONE                  0
# ADDRESSLINE1           0
# ADDRESSLINE2        2521
# CITY                   0
# STATE               1486
# POSTALCODE            76
# COUNTRY                0
# TERRITORY           1074
# CONTACTLASTNAME        0
# CONTACTFIRSTNAME       0
# DEALSIZE               0
# dtype: int64

# %%
df_filled = df.fillna(0) ## i am filling the missing values with 0.

# %%
## filling missing values with the mean of the column
## if values corresponding to a column are int type.
## df['new_column] = df['old_column'].fillna(df[old_column].mean())

# %%
## Renaming Columns
df = df.rename(columns={'ORDERNUMBER':'Serial Number'})

# %%
df
# Out:
#       Serial Number  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0             10107               30      95.70                2  2871.00
# 1             10121               34      81.35                5  2765.90
# 2             10134               41      94.74                2  3884.34
# 3             10145               45      83.26                6  3746.70
# 4             10159               49     100.00               14  5205.27
# ...             ...              ...        ...              ...      ...
# 2818          10350               20     100.00               15  2244.40
# 2819          10373               29     100.00                1  3978.51
# 2820          10386               43     100.00                4  5417.57
# 2821          10397               34      62.24                1  2116.16
# 2822          10414               47      65.52                9  3079.44
#
#             ORDERDATE    STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# ...

# %%
df.head()
# Out:
#    Serial Number  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0          10107               30      95.70                2  2871.00
# 1          10121               34      81.35                5  2765.90
# 2          10134               41      94.74                2  3884.34
# 3          10145               45      83.26                6  3746.70
# 4          10159               49     100.00               14  5205.27
#
#          ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 0   2/24/2003 0:00  Shipped       1         2     2003  ...
# 1    5/7/2003 0:00  Shipped       2         5     2003  ...
# 2    7/1/2003 0:00  Shipped       3         7     2003  ...
# 3   8/25/2003 0:00  Shipped       3         8     2003  ...
# 4  10/10/2003 0:00  Shipped       4        10     2003  ...
#
#                     ADDRESSLINE1  ADDRESSLINE2           CITY STATE  \
# 0        897 Long Airport Avenue           NaN            NYC    NY
# ...

# %%
## Change datatypes
df['Value_new'] = df['PRICEEACH'].astype(int)
df.head()
# Out:
#    Serial Number  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0          10107               30      95.70                2  2871.00
# 1          10121               34      81.35                5  2765.90
# 2          10134               41      94.74                2  3884.34
# 3          10145               45      83.26                6  3746.70
# 4          10159               49     100.00               14  5205.27
#
#          ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ... ADDRESSLINE2  \
# 0   2/24/2003 0:00  Shipped       1         2     2003  ...          NaN
# 1    5/7/2003 0:00  Shipped       2         5     2003  ...          NaN
# 2    7/1/2003 0:00  Shipped       3         7     2003  ...          NaN
# 3   8/25/2003 0:00  Shipped       3         8     2003  ...          NaN
# 4  10/10/2003 0:00  Shipped       4        10     2003  ...          NaN
#
#             CITY STATE POSTALCODE COUNTRY TERRITORY CONTACTLASTNAME  \
# ...

# %%
df
# Out:
#       Serial Number  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0             10107               30      95.70                2  2871.00
# 1             10121               34      81.35                5  2765.90
# 2             10134               41      94.74                2  3884.34
# 3             10145               45      83.26                6  3746.70
# 4             10159               49     100.00               14  5205.27
# ...             ...              ...        ...              ...      ...
# 2818          10350               20     100.00               15  2244.40
# 2819          10373               29     100.00                1  3978.51
# 2820          10386               43     100.00                4  5417.57
# 2821          10397               34      62.24                1  2116.16
# 2822          10414               47      65.52                9  3079.44
#
#             ORDERDATE    STATUS  QTR_ID  MONTH_ID  YEAR_ID  ... ADDRESSLINE2  \
# ...

# %%
df['new value'] = df['QUANTITYORDERED'].apply(lambda x:x**2)

# %%
df.head()
# Out:
#    Serial Number  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0          10107               30      95.70                2  2871.00
# 1          10121               34      81.35                5  2765.90
# 2          10134               41      94.74                2  3884.34
# 3          10145               45      83.26                6  3746.70
# 4          10159               49     100.00               14  5205.27
#
#          ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...           CITY  \
# 0   2/24/2003 0:00  Shipped       1         2     2003  ...            NYC
# 1    5/7/2003 0:00  Shipped       2         5     2003  ...          Reims
# 2    7/1/2003 0:00  Shipped       3         7     2003  ...          Paris
# 3   8/25/2003 0:00  Shipped       3         8     2003  ...       Pasadena
# 4  10/10/2003 0:00  Shipped       4        10     2003  ...  San Francisco
#
#    STATE POSTALCODE COUNTRY TERRITORY CONTACTLASTNAME CONTACTFIRSTNAME  \
# ...

# %%
## Data aggregating and Grouping
grouped_mean = df.groupby('COUNTRY')['PRICEEACH'].mean()
print(grouped_mean)
# Out:
# COUNTRY
# Australia      83.508865
# Austria        86.530182
# Belgium        87.494242
# Canada         85.100714
# Denmark        87.363333
# Finland        83.936413
# France         82.550541
# Germany        83.617742
# Ireland        86.123750
# Italy          82.561062
# Japan          82.505000
# Norway         86.096235
# Philippines    82.499615
# Singapore      83.315190
# Spain          81.995731
# Sweden         86.728246
# Switzerland    87.519032
# UK             82.518750
# USA            83.824353
# Name: PRICEEACH, dtype: float64

# %%
grouping = df.groupby(['COUNTRY'])['PRICEEACH'].agg(['mean','sum','count'])
print(grouping)
# Out:
#                   mean       sum  count
# COUNTRY
# Australia    83.508865  15449.14    185
# Austria      86.530182   4759.16     55
# Belgium      87.494242   2887.31     33
# Canada       85.100714   5957.05     70
# Denmark      87.363333   5503.89     63
# Finland      83.936413   7722.15     92
# France       82.550541  25920.87    314
# Germany      83.617742   5184.30     62
# Ireland      86.123750   1377.98     16
# Italy        82.561062   9329.40    113
# Japan        82.505000   4290.26     52
# Norway       86.096235   7318.18     85
# Philippines  82.499615   2144.99     26
# Singapore    83.315190   6581.90     79
# Spain        81.995731  28042.54    342
# Sweden       86.728246   4943.51     57
# Switzerland  87.519032   2713.09     31
# UK           82.518750  11882.70    144
# USA          83.824353  84159.65   1004

# %%
## merging and joining dataframes
df1 = pd.DataFrame({'Key' : ['a' , 'b' , 'c'], 'Value' : [1 , 2 , 3]})
df2 = pd.DataFrame({'Key' : ['a' , 'b' , 'f'], 'Value' : [4,5,6]})
df1
# Out:
#   Key  Value
# 0   a      1
# 1   b      2
# 2   c      3

# %%
df2
# Out:
#   Key  Value
# 0   a      4
# 1   b      5
# 2   f      6

# %%
pd.merge(df1, df2, on = 'Key', how = 'inner')
# Out:
#   Key  Value_x  Value_y
# 0   a        1        4
# 1   b        2        5

# %%
pd.merge(df1, df2, on = 'Key', how = 'outer')
# Out:
#   Key  Value_x  Value_y
# 0   a      1.0      4.0
# 1   b      2.0      5.0
# 2   c      3.0      NaN
# 3   f      NaN      6.0

# %%
pd.merge(df1, df2, on = 'Key', how = 'left')
# Out:
#   Key  Value_x  Value_y
# 0   a        1      4.0
# 1   b        2      5.0
# 2   c        3      NaN

# %%
pd.merge(df1, df2, on = 'Key', how = 'right')
# Out:
#   Key  Value_x  Value_y
# 0   a      1.0        4
# 1   b      2.0        5
# 2   f      NaN        6
