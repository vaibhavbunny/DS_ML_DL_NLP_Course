# %%
## seaborn is a high level lib built on top of matplotlib that provides a high level interface for drawing attractive
## and informative statistical graphics

# !pip install seaborn

# %%
import seaborn as sns

# %%
# Basic Plotting with Seaborn
tips = sns.load_dataset('tips')
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
## create a scatter plot
import matplotlib.pyplot as plt
sns.scatterplot(x = 'total_bill', y = 'tip', data = tips)
plt.title('Scatter Plot of Total Bill VS Tips')
plt.show()

# %%
## line plot 
sns.lineplot(x = 'size', y = 'total_bill', data = tips)

plt.show()

# %%
# # matplotlib and seaborn can also be used for categorical ploting of datasets.
### Categorical Plots 
## Bar plot

sns.barplot(x = 'day', y = 'total_bill', data = tips)
plt.title('This is Bar Plot of Day VS Total Bill')
# Out:
# Text(0.5, 1.0, 'This is Bar Plot of Day VS Total Bill')

# %%
## Box Plot

sns.boxplot(x = 'day', y = 'total_bill', data = tips)
plt.title('Box Plot of Day VS Total Bill')
# Out:
# Text(0.5, 1.0, 'Box Plot of Day VS Total Bill')

# %%
## Violin Plot 
sns.violinplot(x = 'day', y = 'total_bill', data = tips)
plt.title('Violin Plot of Size VS Total Bill')
plt.show()

# %%
## histograms 
sns.histplot(tips['total_bill'], bins = 10, kde = True)

## with the help of kde i can get the line for distirbution of data.
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %%
## KDE Plot
sns.kdeplot(tips['total_bill'], fill = True)
# Out:
# <Axes: xlabel='total_bill', ylabel='Density'>

# %%
## Pair Plot
sns.pairplot(tips)
## we specifically need to have numerical data in attributes for this particular pairplot data visualization.

# %%
## Heat Map
corr = tips[['total_bill', 'size', 'tip']].corr()
corr
sns.heatmap(corr,annot = True, cmap='coolwarm')
# Out:
# <Axes: >

# %%
import pandas as pd

sales_df = pd.read_csv('sales_data_sample.csv',encoding='latin1')
sales_df.head()
# Out:
#    ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0        10107               30      95.70                2  2871.00
# 1        10121               34      81.35                5  2765.90
# 2        10134               41      94.74                2  3884.34
# 3        10145               45      83.26                6  3746.70
# 4        10159               49     100.00               14  5205.27
#
#          ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 0   2/24/2003 0:00  Shipped       1         2     2003  ...
# 1    5/7/2003 0:00  Shipped       2         5     2003  ...
# 2    7/1/2003 0:00  Shipped       3         7     2003  ...
# 3   8/25/2003 0:00  Shipped       3         8     2003  ...
# 4  10/10/2003 0:00  Shipped       4        10     2003  ...
#
#                     ADDRESSLINE1  ADDRESSLINE2           CITY STATE  \
# 0        897 Long Airport Avenue           NaN            NYC    NY
# ...

# %%
## Now we have moved towards the customized plotting of graphs.
## Plot Total Sales.
plt.figure(figsize=(10,6))
sns.barplot(x = 'COUNTRY', y = 'SALES', data = sales_df, estimator = sum)
# Out:
# <Axes: xlabel='COUNTRY', ylabel='SALES'>

# %%
## Plot Total Sales.
plt.figure(figsize=(10,6))
sns.barplot(x = 'CITY', y = 'SALES', data = sales_df, estimator = sum)
# Out:
# <Axes: xlabel='CITY', ylabel='SALES'>
